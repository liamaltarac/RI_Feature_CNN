# %%
from sympy.stats import P, E, variance, Die, Normal, density, Uniform, VonMises
from sympy import simplify, Symbol, cos, pi

# %%
X, Y = Die('X', 6), Die('Y', 6) # Define two six sided dice
Z = Normal('Z', 0, 1) # Declare a Normal random variable with mean 0, std 1
P(X>3) # Probability X is greater than 3
# Out:
# 1/2

# %%
mu = Symbol("mu")
sigma = Symbol("sigma", positive=True)

mu2 = Symbol("mu2")
sigma2 = Symbol("sigma2", positive=True)


z = Symbol("z")

X = VonMises("x", 0, 1)
Y = Uniform("y", -1, 1)

X.

# %%
variance(cos(X-Y))(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17808\3091722376.py in <module>
# ----> 1 variance(cos(X-Y))(z)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\stats\rv_interface.py in variance(X, condition, **kwargs)
#      78         return Variance(X, condition)
#      79
# ---> 80     return cmoment(X, 2, condition, **kwargs)
#      81
#      82
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\stats\rv_interface.py in cmoment(X, n, condition, evaluate, **kwargs)
#     240     from sympy.stats.symbolic_probability import CentralMoment
#     241     if evaluate:
# --> 242         return CentralMoment(X, n, condition).doit()
#     243     return CentralMoment(X, n, condition).rewrite(Integral)
#     244
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\stats\symbolic_probability.py in doit(self, **hints)
#     675
#     676     def doit(self, **hints):
# --> 677         return self.rewrite(Expectation).doit(**hints)
#     678
#     679     def _eval_rewrite_as_Expectation(self, X, n, condition=None, **kwargs):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\stats\symbolic_probability.py in doit(self, **hints)
#     253
#     254         if deep:
# --> 255             expr = expr.doit(**hints)
#     256
#     257         if not is_random(expr) or isinstance(expr, Expectation):  # expr isn't random?
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in doit(self, **hints)
#    1753         if hints.get('deep', True):
#    1754             terms = [term.doit(**hints) if isinstance(term, Basic) else term
# -> 1755                                          for term in self.args]
#    1756             return self.func(*terms)
#    1757         else:
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1753         if hints.get('deep', True):
#    1754             terms = [term.doit(**hints) if isinstance(term, Basic) else term
# -> 1755                                          for term in self.args]
#    1756             return self.func(*terms)
#    1757         else:
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\operations.py in doit(self, **hints)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\operations.py in <listcomp>(.0)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\operations.py in doit(self, **hints)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\operations.py in <listcomp>(.0)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\stats\symbolic_probability.py in doit(self, **hints)
#     281             return self.func(expr)
#     282         # Otherwise case is simple, pass work off to the ProbabilitySpace
# --> 283         result = pspace(expr).compute_expectation(expr, evaluate=for_rewrite)
#     284         if hasattr(result, 'doit') and for_rewrite:
#     285             return result.doit(**hints)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\stats\rv.py in compute_expectation(self, expr, rvs, evaluate, **kwargs)
#     445             expr = space.compute_expectation(expr, rvs & space.values, evaluate=False, **kwargs)
#     446         if evaluate and hasattr(expr, 'doit'):
# --> 447             return expr.doit(**kwargs)
#     448         return expr
#     449
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     450         function = self.function
#     451         if deep:
# --> 452             function = function.doit(**hints)
#     453         if function.is_zero:
#     454             return S.Zero
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\functions\elementary\piecewise.py in doit(self, **hints)
#     300             if hints.get('deep', True):
#     301                 if isinstance(e, Basic):
# --> 302                     newe = e.doit(**hints)
#     303                     if newe != self:
#     304                         e = newe
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\operations.py in doit(self, **hints)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\operations.py in <listcomp>(.0)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     595                         and not function.is_Poly and
#     596                         (xab[1].has(oo, -oo) or xab[2].has(oo, -oo))):
# --> 597                     ret = try_meijerg(function, xab)
#     598                     if ret is not None:
#     599                         function = ret
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\integrals.py in try_meijerg(function, xab)
#     565                         x, a, b = xab
#     566                         try:
# --> 567                             res = meijerint_definite(function, x, a, b)
#     568                         except NotImplementedError:
#     569                             _debug('NotImplementedError '
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\meijerint.py in meijerint_definite(f, x, a, b)
#    1844                 _debug('  Non-real splitting point.')
#    1845                 continue
# -> 1846             res1 = _meijerint_definite_2(f.subs(x, x + c), x)
#    1847             if res1 is None:
#    1848                 _debug('  But could not compute first integral.')
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\meijerint.py in _meijerint_definite_2(f, x)
#    1974     for g, explanation in _guess_expansion(f, x):
#    1975         _debug('Trying', explanation)
# -> 1976         res = _meijerint_definite_3(g, x)
#    1977         if res:
#    1978             return res
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\meijerint.py in _meijerint_definite_3(f, x)
#    1991     if f.is_Add:
#    1992         _debug('Expanding and evaluating all terms.')
# -> 1993         ress = [_meijerint_definite_4(g, x) for g in f.args]
#    1994         if all(r is not None for r in ress):
#    1995             conds = []
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\meijerint.py in <listcomp>(.0)
#    1991     if f.is_Add:
#    1992         _debug('Expanding and evaluating all terms.')
# -> 1993         ress = [_meijerint_definite_4(g, x) for g in f.args]
#    1994         if all(r is not None for r in ress):
#    1995             conds = []
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\integrals\meijerint.py in _meijerint_definite_4(f, x, only_double)
#    2075                 if only_double:
#    2076                     return res, cond
# -> 2077                 return _my_unpolarify(hyperexpand(res)), cond
#    2078
#    2079
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\simplify\hyperexpand.py in hyperexpand(f, allow_hyper, rewrite, place)
#    2514         if not r.has(nan, zoo, oo, -oo):
#    2515             return r
# -> 2516     return f.replace(hyper, do_replace).replace(meijerg, do_meijer)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in replace(self, query, value, map, simultaneous, exact)
#    1575             return expr
#    1576
# -> 1577         rv = walk(self, rec_replace)
#    1578         return (rv, mapping) if map else rv
#    1579
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1550             if args is not None:
#    1551                 if args:
# -> 1552                     newargs = tuple([walk(a, F) for a in args])
#    1553                     if args != newargs:
#    1554                         rv = rv.func(*newargs)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1550             if args is not None:
#    1551                 if args:
# -> 1552                     newargs = tuple([walk(a, F) for a in args])
#    1553                     if args != newargs:
#    1554                         rv = rv.func(*newargs)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1560                                 if rv == e and e != newargs[i]:
#    1561                                     return rv
# -> 1562                 rv = F(rv)
#    1563             return rv
#    1564
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in rec_replace(expr)
#    1568             result = _query(expr)
#    1569             if result or result == {}:
# -> 1570                 v = _value(expr, result)
#    1571                 if v is not None and v != expr:
#    1572                     if map:
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\basic.py in <lambda>(expr, result)
#    1497                 _value = lambda expr, result: value(*expr.args)
#    1498             elif callable(value):
# -> 1499                 _value = lambda expr, result: value(*expr.args)
#    1500             else:
#    1501                 raise TypeError(
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\simplify\hyperexpand.py in do_meijer(ap, bq, z)
#    2511     def do_meijer(ap, bq, z):
#    2512         r = _meijergexpand(G_Function(ap[0], ap[1], bq[0], bq[1]), z,
# -> 2513                    allow_hyper, rewrite=rewrite, place=place)
#    2514         if not r.has(nan, zoo, oo, -oo):
#    2515             return r
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\simplify\hyperexpand.py in _meijergexpand(func, z0, allow_hyper, rewrite, place)
#    2388
#    2389     t = Dummy('t')
# -> 2390     slater1, cond1 = do_slater(func.an, func.bm, func.ap, func.bq, z, z0)
#    2391
#    2392     def tr(l):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\simplify\hyperexpand.py in do_slater(an, bm, ap, bq, z, zfinal)
#    2322                 premult = (t/k)**bh
#    2323                 hyp = _hyperexpand(Hyper_Function(nap, nbq), harg, ops,
# -> 2324                                    t, premult, bh, rewrite=None)
#    2325                 res += fac * hyp
#    2326             else:
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\simplify\hyperexpand.py in _hyperexpand(func, z, ops0, z0, premult, prem, rewrite)
#    2077     r = carryout_plan(formula, ops) + p
#    2078
# -> 2079     return powdenest(r, polar=True).replace(hyper, hyperexpand_special)
#    2080
#    2081
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\simplify\powsimp.py in powdenest(eq, force, polar)
#     601
#     602     if polar:
# --> 603         eq, rep = polarify(eq)
#     604         return unpolarify(powdenest(unpolarify(eq, exponents_only=True)), rep)
#     605
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\functions\elementary\complexes.py in polarify(eq, subs, lift)
#    1375     if lift:
#    1376         subs = False
# -> 1377     eq = _polarify(sympify(eq), lift)
#    1378     if not subs:
#    1379         return eq
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\functions\elementary\complexes.py in _polarify(eq, lift, pause)
#    1305         return eq
#    1306     if eq.is_number and not pause:
# -> 1307         return polar_lift(eq)
#    1308     if isinstance(eq, Symbol) and not pause and lift:
#    1309         return polar_lift(eq)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     474
#     475         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 476         result = super().__new__(cls, *args, **options)
#     477         if evaluate and isinstance(result, cls) and result.args:
#     478             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     286
#     287         if evaluate:
# --> 288             evaluated = cls.eval(*args)
#     289             if evaluated is not None:
#     290                 return evaluated
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\functions\elementary\complexes.py in eval(cls, arg)
#    1035         from sympy.functions.elementary.complexes import arg as argument
#    1036         if arg.is_number:
# -> 1037             ar = argument(arg)
#    1038             # In general we want to affirm that something is known,
#    1039             # e.g. `not ar.has(argument) and not ar.has(atan)`
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     474
#     475         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 476         result = super().__new__(cls, *args, **options)
#     477         if evaluate and isinstance(result, cls) and result.args:
#     478             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     286
#     287         if evaluate:
# --> 288             evaluated = cls.eval(*args)
#     289             if evaluated is not None:
#     290                 return evaluated
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\functions\elementary\complexes.py in eval(cls, arg)
#     774             return
#     775         x, y = arg_.as_real_imag()
# --> 776         rv = atan2(y, x)
#     777         if rv.is_number:
#     778             return rv
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     474
#     475         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 476         result = super().__new__(cls, *args, **options)
#     477         if evaluate and isinstance(result, cls) and result.args:
#     478             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     286
#     287         if evaluate:
# --> 288             evaluated = cls.eval(*args)
#     289             if evaluated is not None:
#     290                 return evaluated
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\functions\elementary\trigonometric.py in eval(cls, y, x)
#    3443                 return S.Pi*(S.One - Heaviside(x))
#    3444             if x.is_number:
# -> 3445                 return Piecewise((S.Pi, re(x) < 0),
#    3446                                  (0, Ne(x, 0)),
#    3447                                  (S.NaN, True))
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     234             if not isinstance(other, expectedcls):
#     235                 return retval
# --> 236             return func(self, other)
#     237
#     238         return _func
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\expr.py in __lt__(self, other)
#     368     def __lt__(self, other):
#     369         from .relational import StrictLessThan
# --> 370         return StrictLessThan(self, other)
#     371
#     372     def __trunc__(self):
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\sympy\core\relational.py in __new__(cls, lhs, rhs, **options)
#     832             for me in (lhs, rhs):
#     833                 if me.is_extended_real is False:
# --> 834                     raise TypeError("Invalid comparison of non-real %s" % me)
#     835                 if me is S.NaN:
#     836                     raise TypeError("Invalid NaN comparison")
#
# TypeError: Invalid comparison of non-real I*im(exp_polar(-I*pi/2))*erf(sqrt(2)*I*exp_polar(0)*im(exp_polar(I*pi/2))/2)

# %%
import numpy as np

x = np.array([1,3])
y = np.array([8,5])

np.dot(x,y)
# Out:
# 23

# %%
np.linalg.norm(x)
# Out:
# 3.1622776601683795

# %%
np.linalg.norm(y)
# Out:
# 9.433981132056603

# %%
np.cos(np.arctan2(x) - np.arctan2(y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20524\4023989840.py in <module>
# ----> 1 np.cos(np.arctan2(x) - np.arctan2(y))
#
# TypeError: arctan2() takes from 2 to 3 positional arguments but 1 were given
